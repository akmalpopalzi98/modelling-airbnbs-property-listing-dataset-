# %%
import pandas as pd

# %%
pwd
# Out:
# '/Users/akmalpopalzi/Documents/GitHub/modelling-airbnbs-property-listing-dataset-/cleaning_utils'

# %%
df = pd.read_csv('/Users/akmalpopalzi/Documents/GitHub/modelling-airbnbs-property-listing-dataset-/airbnb-property-listings/tabular_data/listing.csv')

# %%
df.head()
# Out:
#                                      ID    Category  \
# 0  f9dcbd09-32ac-41d9-a0b1-fdb2793378cf  Treehouses
# 1  1b4736a7-e73e-45bc-a9b5-d3e7fcf652fd  Treehouses
# 2  d577bc30-2222-4bef-a35e-a9825642aec4  Treehouses
# 3  ca9cbfd4-7798-4e8d-8c17-d5a64fba0abc  Treehouses
# 4  8b2d0f78-16d8-4559-8692-62ebce2a1302  Treehouses
#
#                                               Title  \
# 0                 Red Kite Tree Tent - Ynys Affalon
# 1    Az Alom Cabin - Treehouse Tree to Nature Cabin
# 2                       Cabane Entre Les Pins\n🌲🏕️🌲
# 3  Tree Top Cabin with log burner & private hot tub
# 4                                     Hanging cabin
#
#                                          Description  \
# 0  ['About this space', "Escape to one of these t...
# 1  ['About this space', "Come and spend a romanti...
# 2  ['About this space', 'Rustic cabin between the...
# 3  ['About this space', 'The Tree top cabin is si...
# 4  ['About this space', 'Feel refreshed at this u...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 988 entries, 0 to 987
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    988 non-null    object
#  1   Category              988 non-null    object
#  2   Title                 988 non-null    object
#  3   Description           900 non-null    object
#  4   Amenities             988 non-null    object
#  5   Location              988 non-null    object
#  6   guests                969 non-null    object
#  7   beds                  945 non-null    float64
#  8   bathrooms             888 non-null    float64
#  9   Price_Night           988 non-null    int64
#  10  Cleanliness_rating    890 non-null    float64
#  11  Accuracy_rating       890 non-null    float64
#  12  Communication_rating  890 non-null    float64
#  13  Location_rating       890 non-null    float64
#  14  Check-in_rating       890 non-null    float64
# ...

# %%
df.isna().sum()
# Out:
# ID                        0
# Category                  0
# Title                     0
# Description              88
# Amenities                 0
# Location                  0
# guests                   19
# beds                     43
# bathrooms               100
# Price_Night               0
# Cleanliness_rating       98
# Accuracy_rating          98
# Communication_rating     98
# Location_rating          98
# Check-in_rating          98
# Value_rating             98
# amenities_count           0
# url                       0
# bedrooms                 82
# Unnamed: 19             987
# dtype: int64

# %%
df.columns
# Out:
# Index(['ID', 'Category', 'Title', 'Description', 'Amenities', 'Location',
#        'guests', 'beds', 'bathrooms', 'Price_Night', 'Cleanliness_rating',
#        'Accuracy_rating', 'Communication_rating', 'Location_rating',
#        'Check-in_rating', 'Value_rating', 'amenities_count', 'url', 'bedrooms',
#        'Unnamed: 19'],
#       dtype='object')

# %%
df.Cleanliness_rating.isna
# Out:
# <bound method Series.isna of 0      4.6
# 1      4.3
# 2      4.2
# 3      4.8
# 4      NaN
#       ...
# 983    4.8
# 984    4.8
# 985    4.7
# 986    NaN
# 987    4.9
# Name: Cleanliness_rating, Length: 988, dtype: float64>

# %%
df[['Cleanliness_rating','Accuracy_rating','Communication_rating','Location_rating','Check-in_rating','Value_rating']]
# Out:
#      Cleanliness_rating  Accuracy_rating  Communication_rating  \
# 0                   4.6              4.7                   4.3
# 1                   4.3              4.7                   4.6
# 2                   4.2              4.6                   4.8
# 3                   4.8              4.9                   4.9
# 4                   NaN              NaN                   NaN
# ..                  ...              ...                   ...
# 983                 4.8              5.0                   4.9
# 984                 4.8              5.0                   5.0
# 985                 4.7              4.8                   5.0
# 986                 NaN              NaN                   NaN
# 987                 4.9              4.9                   4.9
#
#      Location_rating  Check-in_rating  Value_rating
# 0                5.0              4.3           4.3
# 1                4.9              4.7           4.5
# ...

# %% [markdown]
# ### Function 1 - remove missing ratings

# %%
def remove_rows_with_missing_ratings(df):
    ratings = df[['Cleanliness_rating','Accuracy_rating','Communication_rating','Location_rating','Check-in_rating','Value_rating']].dropna()
    return ratings

# %%
df.head()
# Out:
#                                      ID    Category  \
# 0  f9dcbd09-32ac-41d9-a0b1-fdb2793378cf  Treehouses
# 1  1b4736a7-e73e-45bc-a9b5-d3e7fcf652fd  Treehouses
# 2  d577bc30-2222-4bef-a35e-a9825642aec4  Treehouses
# 3  ca9cbfd4-7798-4e8d-8c17-d5a64fba0abc  Treehouses
# 4  8b2d0f78-16d8-4559-8692-62ebce2a1302  Treehouses
#
#                                               Title  \
# 0                 Red Kite Tree Tent - Ynys Affalon
# 1    Az Alom Cabin - Treehouse Tree to Nature Cabin
# 2                       Cabane Entre Les Pins\n🌲🏕️🌲
# 3  Tree Top Cabin with log burner & private hot tub
# 4                                     Hanging cabin
#
#                                          Description  \
# 0  ['About this space', "Escape to one of these t...
# 1  ['About this space', "Come and spend a romanti...
# 2  ['About this space', 'Rustic cabin between the...
# 3  ['About this space', 'The Tree top cabin is si...
# 4  ['About this space', 'Feel refreshed at this u...
#
# ...

# %%
df.Description[8]
# Out:
# '[\'About this space\', \'The Domaine proposes to make you live a unique experience in a beautiful place where a perched hut is set up to guarantee absolute privacy to really feel "out of time" to recharge your batteries cut off from civilization.\\nA private outdoor uncovered Jacuzzi awaits you\', \'The space\', \'The space\\nLuxury and nature the hut perched 100% comfort : heating, toilet, shower.\\nAn outdoor Jacuzzi not covered for 3 people\\nA monkey bridge, easy to reach by stairs is open to all without age limit and will please children.\\nPerched 5 meters high, close to the pond which guarantees a unique charm.\\nwith a view of the pond.\\nBreakfast not included but you can bring yours (nespresso available in the cabin)\\nOffice available microwave, fridge and dishes on request\', \'Guest access\', \'Guest access\\nentire accommodation\\nbarbecue in the park on request\', \'Other things to note\', \'Other things to note\\nthe site lends itself to weddings if necessary the cot
# ...

# %%
def combine_description_strings(df):
    descriptions_remove_null = df.Description.dropna()
    pass

# %%
test = df.Description[3]

# %%
test
# Out:
# '[\'About this space\', \'The Tree top cabin is situated in our peaceful woodland in the heart of Snowdonia. It has a shower (hot water included)and w.c and washbasin (no hot water in the washbasin).\\nLighting is provided from a 12v solar panel system.\\nA log burner is provided with free wood.\\nThere is a double bed.\\nThe private wood fired hot tub is situated on a balcony overlooking the woodland area.\\nPet friendly.\\nOutside seating is provided.\', \'The space\', \'The space\\nThis unique glamping experience has everything you need for a restful and idyllic break from everyday life. Wake up to bird song and the sound of the stream. Enjoy your own exclusive hot tub whilst sipping a glass of bubbly. Our Cabin is fully insulated and has everything you need for that perfect "rustic" getaway without compromising on quality and convenience.\\n\\nALL bedding and towels are included in your stay. You may like to bring extra towels for hot tub usage.\\n\\nA small log burner inside to 
# ...

# %%
test.startswith('[')
# Out:
# True

# %%
test2 = test.replace('About this space','')

# %%
test3 = test2.replace('[','')

# %%
test3
# Out:
# '\'\', \'The Tree top cabin is situated in our peaceful woodland in the heart of Snowdonia. It has a shower (hot water included)and w.c and washbasin (no hot water in the washbasin).\\nLighting is provided from a 12v solar panel system.\\nA log burner is provided with free wood.\\nThere is a double bed.\\nThe private wood fired hot tub is situated on a balcony overlooking the woodland area.\\nPet friendly.\\nOutside seating is provided.\', \'The space\', \'The space\\nThis unique glamping experience has everything you need for a restful and idyllic break from everyday life. Wake up to bird song and the sound of the stream. Enjoy your own exclusive hot tub whilst sipping a glass of bubbly. Our Cabin is fully insulated and has everything you need for that perfect "rustic" getaway without compromising on quality and convenience.\\n\\nALL bedding and towels are included in your stay. You may like to bring extra towels for hot tub usage.\\n\\nA small log burner inside to keep you nice and
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 988 entries, 0 to 987
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    988 non-null    object
#  1   Category              988 non-null    object
#  2   Title                 988 non-null    object
#  3   Description           900 non-null    object
#  4   Amenities             988 non-null    object
#  5   Location              988 non-null    object
#  6   guests                969 non-null    object
#  7   beds                  945 non-null    float64
#  8   bathrooms             888 non-null    float64
#  9   Price_Night           988 non-null    int64
#  10  Cleanliness_rating    890 non-null    float64
#  11  Accuracy_rating       890 non-null    float64
#  12  Communication_rating  890 non-null    float64
#  13  Location_rating       890 non-null    float64
#  14  Check-in_rating       890 non-null    float64
# ...

# %%
from ast import literal_eval
b = df["Description"][1] = literal_eval(df["Description"][1])
# Out:
# /var/folders/j7/wpvkrkss313_f_v160vb65h80000gn/T/ipykernel_1557/604152607.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b = df["Description"][1] = literal_eval(df["Description"][1])

# %%
b
# Out:
# ['About this space',
#  "Come and spend a romantic stay with a couple or family, on the Domaine de l 'Arbre in Cabane\n\nA very pretty forest of 5 hectares shelters 8 beautiful huts they all have the dream names, unique and unprecedented.\n\nThey are housed in centuries-old trees out of sight, in osmosis with nature.\n\nThe site is preserved, your peace is assured. Nature is everywhere\n\nA treehouse to indulge, relax and go where no one will be looking for you!",
#  'The space',
#  'The space\nCabin perched in trees 8 meters high.\nThis cabin is beautiful. Its access via a board walkway and its platform adjoining 3 individual beds seduce them to the highest degree. It has a capacity of 3 people.',
#  'Guest access',
#  'Guest access\nYou will have access to the entire cabin, forest and park.\nSanitary facilities (showers and toilets) are at the reception, a 3-minute walk.',
#  'Other things to note',
#  'Other things to note\nAre you ready for an unusual stay?']

# %%
a = AirbnbDataPrep()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/akmalpopalzi/Documents/GitHub/modelling-airbnbs-property-listing-dataset-/cleaning_utils/tabular_data_testing.ipynb Cell 24 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/akmalpopalzi/Documents/GitHub/modelling-airbnbs-property-listing-dataset-/cleaning_utils/tabular_data_testing.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> a = AirbnbDataPrep()
#
# NameError: name 'AirbnbDataPrep' is not defined

# %%
a = df.reset_index(drop = True, inplace = True)

# %%
a

# %%
a

# %%
df.drop('Unnamed: 19', inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Untitled-1.ipynb Cell 28 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X55sdW50aXRsZWQ%3D?line=0'>1</a> df.drop('Unnamed: 19', inplace = True)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4957, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df.colummns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Untitled-1.ipynb Cell 29 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X56sdW50aXRsZWQ%3D?line=0'>1</a> df.colummns
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'colummns'

# %%
df
# Out:
#                                        ID    Category  \
# 0    f9dcbd09-32ac-41d9-a0b1-fdb2793378cf  Treehouses
# 1    1b4736a7-e73e-45bc-a9b5-d3e7fcf652fd  Treehouses
# 2    d577bc30-2222-4bef-a35e-a9825642aec4  Treehouses
# 3    ca9cbfd4-7798-4e8d-8c17-d5a64fba0abc  Treehouses
# 4    8b2d0f78-16d8-4559-8692-62ebce2a1302  Treehouses
# ..                                    ...         ...
# 983  4fea5054-f999-4c07-addc-67e4d893deab  Beachfront
# 984  282118e2-049e-4d9f-b2f2-b47477881b07  Beachfront
# 985  9ebf9cec-624e-480e-8704-dffa7cb1fe51  Beachfront
# 986  de8a45c7-0a1e-48ed-916d-6d1ad8d9f771  Beachfront
# 987  d2b06c80-c643-485d-a24b-15d0811a3166  Beachfront
#
#                                                  Title  \
# 0                    Red Kite Tree Tent - Ynys Affalon
# 1       Az Alom Cabin - Treehouse Tree to Nature Cabin
# 2                          Cabane Entre Les Pins\n🌲🏕️🌲
# 3     Tree Top Cabin with log burner & private hot tub
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Category', 'Title', 'Description', 'Amenities', 'Location',
#        'guests', 'beds', 'bathrooms', 'Price_Night', 'Cleanliness_rating',
#        'Accuracy_rating', 'Communication_rating', 'Location_rating',
#        'Check-in_rating', 'Value_rating', 'amenities_count', 'url', 'bedrooms',
#        'Unnamed: 19'],
#       dtype='object')

# %%
df.drop('Unnamed: 19', inplace = True, axis = 1)

# %%
df
# Out:
#                                        ID    Category  \
# 0    f9dcbd09-32ac-41d9-a0b1-fdb2793378cf  Treehouses
# 1    1b4736a7-e73e-45bc-a9b5-d3e7fcf652fd  Treehouses
# 2    d577bc30-2222-4bef-a35e-a9825642aec4  Treehouses
# 3    ca9cbfd4-7798-4e8d-8c17-d5a64fba0abc  Treehouses
# 4    8b2d0f78-16d8-4559-8692-62ebce2a1302  Treehouses
# ..                                    ...         ...
# 983  4fea5054-f999-4c07-addc-67e4d893deab  Beachfront
# 984  282118e2-049e-4d9f-b2f2-b47477881b07  Beachfront
# 985  9ebf9cec-624e-480e-8704-dffa7cb1fe51  Beachfront
# 986  de8a45c7-0a1e-48ed-916d-6d1ad8d9f771  Beachfront
# 987  d2b06c80-c643-485d-a24b-15d0811a3166  Beachfront
#
#                                                  Title  \
# 0                    Red Kite Tree Tent - Ynys Affalon
# 1       Az Alom Cabin - Treehouse Tree to Nature Cabin
# 2                          Cabane Entre Les Pins\n🌲🏕️🌲
# 3     Tree Top Cabin with log burner & private hot tub
# ...

# %%
for i in range(len(df.Description)):
    pass

# %%
df.Description[0] = literal_eval(df.Description[0])
# Out:
# /var/folders/j7/wpvkrkss313_f_v160vb65h80000gn/T/ipykernel_1557/3739021685.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Description[0] = literal_eval(df.Description[0])

# %%
df.Description[0]
# Out:
# ['About this space',
#  "Escape to one of these two fabulous Tree Tents. Suspended high above the canopy, it’s time to appreciate life from a new perspective. Featured on George Clarke’s Amazing Spaces, these Tree Tents are a feat of aviation technology. Tree Tent comes complete with fire pit, outdoor kitchen and shower with hot water. You’ll discover a comfortable bed and cosy wood burning stove. Part of the Red Kite Estate, along with our barn and its sister tree tent, the first ever built in the UK, Dragon's Egg.",
#  'The space',
# ...

# %%
df.Description[1]
# Out:
# ['About this space',
#  "Come and spend a romantic stay with a couple or family, on the Domaine de l 'Arbre in Cabane\n\nA very pretty forest of 5 hectares shelters 8 beautiful huts they all have the dream names, unique and unprecedented.\n\nThey are housed in centuries-old trees out of sight, in osmosis with nature.\n\nThe site is preserved, your peace is assured. Nature is everywhere\n\nA treehouse to indulge, relax and go where no one will be looking for you!",
#  'The space',
#  'The space\nCabin perched in trees 8 meters high.\nThis cabin is beautiful. Its access via a board walkway and its platform adjoining 3 individual beds seduce them to the highest degree. It has a capacity of 3 people.',
#  'Guest access',
#  'Guest access\nYou will have access to the entire cabin, forest and park.\nSanitary facilities (showers and toilets) are at the reception, a 3-minute walk.',
#  'Other things to note',
#  'Other things to note\nAre you ready for an unusual stay?']

# %%
df.Description[987]
# Out:
# "['About this space', 'Sea Scenes is a homely two bedroom groundfloor apartment located on Hayling’s beautiful stretch of beach and perfectly situated for stunning views across the Solent.\\n\\nHayling Island is ideal for holiday makers and families as it retains all the attractions of a traditional seaside resort. One of the biggest attractions is the Funland Amusement Park at Beachlands, which has everything from roller coasters to a games arcade and a soft play area. The Hayling Seaside Railway that runs from Beachlands to Eastoke Corner is equally popular.\\n\\nThe island is also well known for its watersports – in fact windsurfing was invented here – and miles of glorious seafront. The local water is perfect for sailing, windsurfing, power boating, jet skiing and more.\\n\\nThere are various great places to eat if you don’t feel like cooking, from nice restaurants to pubs and of course a wide range of takeaways. Hayling is also well served by shops, so anything you need during y
# ...

# %%
df.Description.dropna(inplace = True)

# %%
df.Description
# Out:
# 0      [About this space, Escape to one of these two ...
# 1      [About this space, Come and spend a romantic s...
# 2      ['About this space', 'Rustic cabin between the...
# 3      ['About this space', 'The Tree top cabin is si...
# 4      ['About this space', 'Feel refreshed at this u...
#                              ...
# 983    ['About this space', 'Light roomy space with o...
# 984    ['About this space', 'This specious two bedroo...
# 985    ['About this space', 'With all the modern amen...
# 986    ['About this space', 'Sleeps 10. A large Beach...
# 987    ['About this space', 'Sea Scenes is a homely t...
# Name: Description, Length: 988, dtype: object

# %%
df[['Cleanliness_rating','Accuracy_rating','Communication_rating','Location_rating','Check-in_rating','Value_rating']].dropna(inplace = True)
# Out:
# /var/folders/j7/wpvkrkss313_f_v160vb65h80000gn/T/ipykernel_1557/3853597702.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['Cleanliness_rating','Accuracy_rating','Communication_rating','Location_rating','Check-in_rating','Value_rating']].dropna(inplace = True)

# %%
df
# Out:
#                                        ID    Category  \
# 0    f9dcbd09-32ac-41d9-a0b1-fdb2793378cf  Treehouses
# 1    1b4736a7-e73e-45bc-a9b5-d3e7fcf652fd  Treehouses
# 2    d577bc30-2222-4bef-a35e-a9825642aec4  Treehouses
# 3    ca9cbfd4-7798-4e8d-8c17-d5a64fba0abc  Treehouses
# 4    8b2d0f78-16d8-4559-8692-62ebce2a1302  Treehouses
# ..                                    ...         ...
# 983  4fea5054-f999-4c07-addc-67e4d893deab  Beachfront
# 984  282118e2-049e-4d9f-b2f2-b47477881b07  Beachfront
# 985  9ebf9cec-624e-480e-8704-dffa7cb1fe51  Beachfront
# 986  de8a45c7-0a1e-48ed-916d-6d1ad8d9f771  Beachfront
# 987  d2b06c80-c643-485d-a24b-15d0811a3166  Beachfront
#
#                                                  Title  \
# 0                    Red Kite Tree Tent - Ynys Affalon
# 1       Az Alom Cabin - Treehouse Tree to Nature Cabin
# 2                          Cabane Entre Les Pins\n🌲🏕️🌲
# 3     Tree Top Cabin with log burner & private hot tub
# ...

# %%
df.isna().sum()
# Out:
# ID                        0
# Category                  0
# Title                     0
# Description              88
# Amenities                 0
# Location                  0
# guests                   19
# beds                     43
# bathrooms               100
# Price_Night               0
# Cleanliness_rating       98
# Accuracy_rating          98
# Communication_rating     98
# Location_rating          98
# Check-in_rating          98
# Value_rating             98
# amenities_count           0
# url                       0
# bedrooms                 82
# dtype: int64

# %%
df = pd.read_csv('/Users/akmalpopalzi/Documents/GitHub/modelling-airbnbs-property-listing-dataset-/airbnb-property-listings/tabular_data/listing.csv')

# %%
df.Description[0]
# Out:
# '[\'About this space\', "Escape to one of these two fabulous Tree Tents. Suspended high above the canopy, it’s time to appreciate life from a new perspective. Featured on George Clarke’s Amazing Spaces, these Tree Tents are a feat of aviation technology. Tree Tent comes complete with fire pit, outdoor kitchen and shower with hot water. You’ll discover a comfortable bed and cosy wood burning stove. Part of the Red Kite Estate, along with our barn and its sister tree tent, the first ever built in the UK, Dragon\'s Egg.", \'The space\', \'The space\\nThe true joy of this place is how wonderfully simple it is (aviation technology aside). Days are filled with fireside discussions, wildlife watching and stunningly beautiful walks. With the nearest mobile signal a ten minute walk away, it’s a great place to ditch the digital and truly escape. Head over the bridge to your own private deck that happily houses a clever outdoor-kitchen and shower (complete with hot water). It’s the perfect spot
# ...

# %%
df.dropna(subset = ['Description', 'Value_rating'], inplace = True)

# %%
df.isna().sum()
# Out:
# ID                        0
# Category                  0
# Title                     0
# Description               0
# Amenities                 0
# Location                  0
# guests                   15
# beds                     29
# bathrooms                65
# Price_Night               0
# Cleanliness_rating        0
# Accuracy_rating           0
# Communication_rating      0
# Location_rating           0
# Check-in_rating           0
# Value_rating              0
# amenities_count           0
# url                       0
# bedrooms                 70
# Unnamed: 19             829
# dtype: int64

# %%
df.Description[3]
# Out:
# '[\'About this space\', \'The Tree top cabin is situated in our peaceful woodland in the heart of Snowdonia. It has a shower (hot water included)and w.c and washbasin (no hot water in the washbasin).\\nLighting is provided from a 12v solar panel system.\\nA log burner is provided with free wood.\\nThere is a double bed.\\nThe private wood fired hot tub is situated on a balcony overlooking the woodland area.\\nPet friendly.\\nOutside seating is provided.\', \'The space\', \'The space\\nThis unique glamping experience has everything you need for a restful and idyllic break from everyday life. Wake up to bird song and the sound of the stream. Enjoy your own exclusive hot tub whilst sipping a glass of bubbly. Our Cabin is fully insulated and has everything you need for that perfect "rustic" getaway without compromising on quality and convenience.\\n\\nALL bedding and towels are included in your stay. You may like to bring extra towels for hot tub usage.\\n\\nA small log burner inside to 
# ...

# %%
df = pd.read_csv('/Users/akmalpopalzi/Documents/GitHub/modelling-airbnbs-property-listing-dataset-/airbnb-property-listings/tabular_data/listing.csv')

# %%
df.iloc[586]
# Out:
# ID                                   4c917b3c-d693-4ee4-a321-f5babc728dc9
# Category                                                    Amazing pools
# Title                                       Stunning Cotswolds Water Park
# Description                                            sleeps 6 with pool
# Amenities               ['About this space', 'Enjoy a discount for boo...
# Location                ['What this place offers', 'Bathroom', 'Hair d...
# guests                            Somerford Keynes England United Kingdom
# beds                                                                  6.0
# bathrooms                                                             4.0
# Price_Night                                                             3
# Cleanliness_rating                                                  200.0
# Accuracy_rating                                                       4.8
# Communication_rating                                                  4.9
# ...

# %%
df.drop('Unnamed: 19', axis = 1, inplace = True)

# %%
df
# Out:
#                                        ID    Category  \
# 0    f9dcbd09-32ac-41d9-a0b1-fdb2793378cf  Treehouses
# 1    1b4736a7-e73e-45bc-a9b5-d3e7fcf652fd  Treehouses
# 2    d577bc30-2222-4bef-a35e-a9825642aec4  Treehouses
# 3    ca9cbfd4-7798-4e8d-8c17-d5a64fba0abc  Treehouses
# 4    8b2d0f78-16d8-4559-8692-62ebce2a1302  Treehouses
# ..                                    ...         ...
# 983  4fea5054-f999-4c07-addc-67e4d893deab  Beachfront
# 984  282118e2-049e-4d9f-b2f2-b47477881b07  Beachfront
# 985  9ebf9cec-624e-480e-8704-dffa7cb1fe51  Beachfront
# 986  de8a45c7-0a1e-48ed-916d-6d1ad8d9f771  Beachfront
# 987  d2b06c80-c643-485d-a24b-15d0811a3166  Beachfront
#
#                                                  Title  \
# 0                    Red Kite Tree Tent - Ynys Affalon
# 1       Az Alom Cabin - Treehouse Tree to Nature Cabin
# 2                          Cabane Entre Les Pins\n🌲🏕️🌲
# 3     Tree Top Cabin with log burner & private hot tub
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 988 entries, 0 to 987
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    988 non-null    object
#  1   Category              988 non-null    object
#  2   Title                 988 non-null    object
#  3   Description           900 non-null    object
#  4   Amenities             988 non-null    object
#  5   Location              988 non-null    object
#  6   guests                969 non-null    object
#  7   beds                  945 non-null    float64
#  8   bathrooms             888 non-null    float64
#  9   Price_Night           988 non-null    int64
#  10  Cleanliness_rating    890 non-null    float64
#  11  Accuracy_rating       890 non-null    float64
#  12  Communication_rating  890 non-null    float64
#  13  Location_rating       890 non-null    float64
#  14  Check-in_rating       890 non-null    float64
# ...

# %%
df.Category = df.Category.astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 988 entries, 0 to 987
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    988 non-null    object
#  1   Category              988 non-null    category
#  2   Title                 988 non-null    object
#  3   Description           900 non-null    object
#  4   Amenities             988 non-null    object
#  5   Location              988 non-null    object
#  6   guests                969 non-null    object
#  7   beds                  945 non-null    float64
#  8   bathrooms             888 non-null    float64
#  9   Price_Night           988 non-null    int64
#  10  Cleanliness_rating    890 non-null    float64
#  11  Accuracy_rating       890 non-null    float64
#  12  Communication_rating  890 non-null    float64
#  13  Location_rating       890 non-null    float64
# ...

# %%
df.drop(index = 586, inplace = True)

# %%
df.iloc[586]
# Out:
# ID                                   943e9242-7cfe-4db2-bb56-d7147fef352e
# Category                                                    Amazing pools
# Title                    The Burrow - Luxurious Pet Friendly, 3 Bed Lodge
# Description             ['About this space', "Set in a peaceful area o...
# Amenities               ['What this place offers', 'Bathroom', 'Shampo...
# Location                                  Cotswold England United Kingdom
# guests                                                                  6
# beds                                                                  5.0
# bathrooms                                                             1.5
# Price_Night                                                           163
# Cleanliness_rating                                                    5.0
# Accuracy_rating                                                       4.9
# Communication_rating                                                  4.9
# ...

# %%
df
# Out:
#                                        ID    Category  \
# 0    f9dcbd09-32ac-41d9-a0b1-fdb2793378cf  Treehouses
# 1    1b4736a7-e73e-45bc-a9b5-d3e7fcf652fd  Treehouses
# 2    d577bc30-2222-4bef-a35e-a9825642aec4  Treehouses
# 3    ca9cbfd4-7798-4e8d-8c17-d5a64fba0abc  Treehouses
# 4    8b2d0f78-16d8-4559-8692-62ebce2a1302  Treehouses
# ..                                    ...         ...
# 983  4fea5054-f999-4c07-addc-67e4d893deab  Beachfront
# 984  282118e2-049e-4d9f-b2f2-b47477881b07  Beachfront
# 985  9ebf9cec-624e-480e-8704-dffa7cb1fe51  Beachfront
# 986  de8a45c7-0a1e-48ed-916d-6d1ad8d9f771  Beachfront
# 987  d2b06c80-c643-485d-a24b-15d0811a3166  Beachfront
#
#                                                  Title  \
# 0                    Red Kite Tree Tent - Ynys Affalon
# 1       Az Alom Cabin - Treehouse Tree to Nature Cabin
# 2                          Cabane Entre Les Pins\n🌲🏕️🌲
# 3     Tree Top Cabin with log burner & private hot tub
# ...

# %%
df[df.Category == 'Amazing Pools']
# Out:
# Empty DataFrame
# Columns: [ID, Category, Title, Description, Amenities, Location, guests, beds, bathrooms, Price_Night, Cleanliness_rating, Accuracy_rating, Communication_rating, Location_rating, Check-in_rating, Value_rating, amenities_count, url, bedrooms]
# Index: []

# %%
df.head()
# Out:
#                                      ID    Category  \
# 0  f9dcbd09-32ac-41d9-a0b1-fdb2793378cf  Treehouses
# 1  1b4736a7-e73e-45bc-a9b5-d3e7fcf652fd  Treehouses
# 2  d577bc30-2222-4bef-a35e-a9825642aec4  Treehouses
# 3  ca9cbfd4-7798-4e8d-8c17-d5a64fba0abc  Treehouses
# 4  8b2d0f78-16d8-4559-8692-62ebce2a1302  Treehouses
#
#                                               Title  \
# 0                 Red Kite Tree Tent - Ynys Affalon
# 1    Az Alom Cabin - Treehouse Tree to Nature Cabin
# 2                       Cabane Entre Les Pins\n🌲🏕️🌲
# 3  Tree Top Cabin with log burner & private hot tub
# 4                                     Hanging cabin
#
#                                          Description  \
# 0  ['About this space', "Escape to one of these t...
# 1  ['About this space', "Come and spend a romanti...
# 2  ['About this space', 'Rustic cabin between the...
# 3  ['About this space', 'The Tree top cabin is si...
# 4  ['About this space', 'Feel refreshed at this u...
#
# ...

# %%
df.isna().sum()
# Out:
# ID                        0
# Category                  0
# Title                     0
# Description              88
# Amenities                 0
# Location                  0
# guests                   19
# beds                     43
# bathrooms               100
# Price_Night               0
# Cleanliness_rating       98
# Accuracy_rating          98
# Communication_rating     98
# Location_rating          98
# Check-in_rating          98
# Value_rating             98
# amenities_count           0
# url                       0
# bedrooms                 82
# dtype: int64

# %%
df.dropna(subset = ['Description','Cleanliness_rating','Accuracy_rating',"Communication_rating","Location_rating","Check-in_rating","Value_rating"], inplace = True)

# %%
df.isna().sum()
# Out:
# ID                       0
# Category                 0
# Title                    0
# Description              0
# Amenities                0
# Location                 0
# guests                  15
# beds                    29
# bathrooms               65
# Price_Night              0
# Cleanliness_rating       0
# Accuracy_rating          0
# Communication_rating     0
# Location_rating          0
# Check-in_rating          0
# Value_rating             0
# amenities_count          0
# url                      0
# bedrooms                70
# dtype: int64

# %%
df.reset_index(drop = True, inplace = True)

# %%
for i in range(len(df.Description)):
    df.Description[i] = literal_eval(df.Description[i])
# Out:
# /var/folders/j7/wpvkrkss313_f_v160vb65h80000gn/T/ipykernel_1557/65143504.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Description[i] = literal_eval(df.Description[i])

# %%
df.Description[0]
# Out:
# ['About this space',
#  "Escape to one of these two fabulous Tree Tents. Suspended high above the canopy, it’s time to appreciate life from a new perspective. Featured on George Clarke’s Amazing Spaces, these Tree Tents are a feat of aviation technology. Tree Tent comes complete with fire pit, outdoor kitchen and shower with hot water. You’ll discover a comfortable bed and cosy wood burning stove. Part of the Red Kite Estate, along with our barn and its sister tree tent, the first ever built in the UK, Dragon's Egg.",
#  'The space',
# ...

# %%
phrases = ['About this space',
           'The space',
           '',
           "  ",
           " "
           'Other things to note',
           'Guest access']

# %%
for index, values in enumerate(df.Description[0]):
        print(index,values)
        if values in phrases:
                df.Description[0].pop(index)
# Out:
# 0 About this space
# 1 The space
# 2
# 3

# %%
df.Description[0]
# Out:
# ["Escape to one of these two fabulous Tree Tents. Suspended high above the canopy, it’s time to appreciate life from a new perspective. Featured on George Clarke’s Amazing Spaces, these Tree Tents are a feat of aviation technology. Tree Tent comes complete with fire pit, outdoor kitchen and shower with hot water. You’ll discover a comfortable bed and cosy wood burning stove. Part of the Red Kite Estate, along with our barn and its sister tree tent, the first ever built in the UK, Dragon's Egg.",
# ...

# %%
df.head()
# Out:
#                                      ID    Category  \
# 0  f9dcbd09-32ac-41d9-a0b1-fdb2793378cf  Treehouses
# 1  1b4736a7-e73e-45bc-a9b5-d3e7fcf652fd  Treehouses
# 2  d577bc30-2222-4bef-a35e-a9825642aec4  Treehouses
# 3  ca9cbfd4-7798-4e8d-8c17-d5a64fba0abc  Treehouses
# 4  cfe479b9-c8f8-44af-9bc6-46ede9f14bb5  Treehouses
#
#                                               Title  \
# 0                 Red Kite Tree Tent - Ynys Affalon
# 1    Az Alom Cabin - Treehouse Tree to Nature Cabin
# 2                       Cabane Entre Les Pins\n🌲🏕️🌲
# 3  Tree Top Cabin with log burner & private hot tub
# 4                       Treehouse near Paris Disney
#
#                                          Description  \
# 0  [Escape to one of these two fabulous Tree Tent...
# 1  [About this space, Come and spend a romantic s...
# 2  [About this space, Rustic cabin between the pi...
# 3  [About this space, The Tree top cabin is situa...
# 4  [About this space, Charming cabin nestled in t...
#
# ...

# %%
df.isna().sum()
# Out:
# ID                       0
# Category                 0
# Title                    0
# Description              0
# Amenities                0
# Location                 0
# guests                  15
# beds                    29
# bathrooms               65
# Price_Night              0
# Cleanliness_rating       0
# Accuracy_rating          0
# Communication_rating     0
# Location_rating          0
# Check-in_rating          0
# Value_rating             0
# amenities_count          0
# url                      0
# bedrooms                70
# dtype: int64

# %%
b = df.copy()

# %%
b.head()
# Out:
#                                      ID    Category  \
# 0  f9dcbd09-32ac-41d9-a0b1-fdb2793378cf  Treehouses
# 1  1b4736a7-e73e-45bc-a9b5-d3e7fcf652fd  Treehouses
# 2  d577bc30-2222-4bef-a35e-a9825642aec4  Treehouses
# 3  ca9cbfd4-7798-4e8d-8c17-d5a64fba0abc  Treehouses
# 4  cfe479b9-c8f8-44af-9bc6-46ede9f14bb5  Treehouses
#
#                                               Title  \
# 0                 Red Kite Tree Tent - Ynys Affalon
# 1    Az Alom Cabin - Treehouse Tree to Nature Cabin
# 2                       Cabane Entre Les Pins\n🌲🏕️🌲
# 3  Tree Top Cabin with log burner & private hot tub
# 4                       Treehouse near Paris Disney
#
#                                          Description  \
# 0  [Escape to one of these two fabulous Tree Tent...
# 1  [About this space, Come and spend a romantic s...
# 2  [About this space, Rustic cabin between the pi...
# 3  [About this space, The Tree top cabin is situa...
# 4  [About this space, Charming cabin nestled in t...
#
# ...

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 829 entries, 0 to 828
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    829 non-null    object
#  1   Category              829 non-null    category
#  2   Title                 829 non-null    object
#  3   Description           829 non-null    object
#  4   Amenities             829 non-null    object
#  5   Location              829 non-null    object
#  6   guests                814 non-null    object
#  7   beds                  800 non-null    float64
#  8   bathrooms             764 non-null    float64
#  9   Price_Night           829 non-null    int64
#  10  Cleanliness_rating    829 non-null    float64
#  11  Accuracy_rating       829 non-null    float64
#  12  Communication_rating  829 non-null    float64
#  13  Location_rating       829 non-null    float64
# ...

# %%
columns = ['guests','beds', 'bathrooms', 'bedrooms']

# %%
for item in columns:
    print(df[item].isna().sum())
# Out:
# 15
# 29
# 65
# 70

# %%
df['guests'] = df['guests'].where(df['guests'].isin(['no', 'n/a', 'N/A','NaN']), 1)

# %%
df.guests.isna().sum()
# Out:
# 0

# %%
columns = ['guests','beds', 'bathrooms', 'bedrooms']
for item in columns:
     b[item] =b[item].where(df[item].isin(['no', 'n/a', 'N/A','NaN']), 1)

# %%
b.isna().sum()
# Out:
# ID                      0
# Category                0
# Title                   0
# Description             0
# Amenities               0
# Location                0
# guests                  0
# beds                    0
# bathrooms               0
# Price_Night             0
# Cleanliness_rating      0
# Accuracy_rating         0
# Communication_rating    0
# Location_rating         0
# Check-in_rating         0
# Value_rating            0
# amenities_count         0
# url                     0
# bedrooms                0
# dtype: int64

# %%
import pandas as pd
from ast import literal_eval


class AirbnbDataPrep:
    def __init__(self):
        self.df = pd.read_csv('/Users/akmalpopalzi/Documents/GitHub/modelling-airbnbs-property-listing-dataset-/airbnb-property-listings/tabular_data/listing.csv')

    def initial_cleaning(self):
        self.df.Category = self.df.Category.astype('category')
        self.df.drop(index = 586, inplace = True)
        self.df.drop('Unnamed: 19', axis = 1, inplace = True)
        self.df.reset_index(drop = True, inplace = True)
        return self.df
        
        
        
    def remove_rows_with_missing_ratings(self):
        self.df.dropna(subset = ['Description','Cleanliness_rating','Accuracy_rating',"Communication_rating","Location_rating","Check-in_rating","Value_rating"], inplace = True)
        self.df.reset_index(drop = True, inplace = True)

    
    def clean_description_strings(self):
        # convert string into list of strings
        for i in range(len(self.df.Description)):
            self.df.Description[i] = literal_eval(self.df.Description[i])

        # remove extra words and phrases
        phrases = ['About this space',
           'The space',
           '',
           "  ",
           " "
           'Other things to note',
           'Guest access']
        
        for index, value in enumerate(self.df.Description):
             for desc_index, desc in enumerate(value):
                  if value in phrases:
                       self.df.Description[desc_index].pop(desc_index)


    def set_feature_values(self):
            columns = ['guests','beds', 'bathrooms', 'bedrooms']
            for item in columns:
                self.df[item] = self.df[item].where(self.df[item].isin(['no', 'n/a', 'N/A','NaN']), 1)

# %%
import pandas as pd
from ast import literal_eval


class AirbnbDataPrep:
    def __init__(self):
        self.df = pd.read_csv('/Users/akmalpopalzi/Documents/GitHub/modelling-airbnbs-property-listing-dataset-/airbnb-property-listings/tabular_data/listing.csv')

    def initial_cleaning(self):
        self.df.Category = self.df.Category.astype('category')
        self.df.drop(index = 586, inplace = True)
        self.df.drop('Unnamed: 19', axis = 1, inplace = True)
        self.df.reset_index(drop = True, inplace = True)
        return self.df
    

    def remove_rows_with_missing_ratings(self):
        self.df.dropna(subset = ['Description','Cleanliness_rating','Accuracy_rating',"Communication_rating","Location_rating","Check-in_rating","Value_rating"], inplace = True)
        self.df.reset_index(drop = True, inplace = True)
        return self.df
    

    def clean_description_strings(self):
        # convert string into list of strings
        for i in range(len(self.df.Description)):
            self.df.Description[i] = literal_eval(self.df.Description[i])

        # remove extra words and phrases
        phrases = ['About this space',
           'The space',
           '',
           "  ",
           " "
           'Other things to note',
           'Guest access']
        
        for index, value in enumerate(self.df.Description):
             for desc_index, desc in enumerate(value):
                  if desc in phrases:
                       self.df.Description[index].pop(desc_index)

        return self.df

# %%
data = AirbnbDataPrep()

# %%
data.initial_cleaning().head().isna().sum()
# Out:
# ID                      0
# Category                0
# Title                   0
# Description             0
# Amenities               0
# Location                0
# guests                  0
# beds                    1
# bathrooms               1
# Price_Night             0
# Cleanliness_rating      1
# Accuracy_rating         1
# Communication_rating    1
# Location_rating         1
# Check-in_rating         1
# Value_rating            1
# amenities_count         0
# url                     0
# bedrooms                2
# dtype: int64

# %%
data.remove_rows_with_missing_ratings().isna().sum()
# Out:
# ID                       0
# Category                 0
# Title                    0
# Description              0
# Amenities                0
# Location                 0
# guests                  15
# beds                    29
# bathrooms               65
# Price_Night              0
# Cleanliness_rating       0
# Accuracy_rating          0
# Communication_rating     0
# Location_rating          0
# Check-in_rating          0
# Value_rating             0
# amenities_count          0
# url                      0
# bedrooms                70
# dtype: int64

# %%
a = data.clean_description_strings()
# Out:
# /var/folders/j7/wpvkrkss313_f_v160vb65h80000gn/T/ipykernel_1557/1900447734.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df.Description[i] = literal_eval(self.df.Description[i])

# %%
a.Description[0]
# Out:
# ["Escape to one of these two fabulous Tree Tents. Suspended high above the canopy, it’s time to appreciate life from a new perspective. Featured on George Clarke’s Amazing Spaces, these Tree Tents are a feat of aviation technology. Tree Tent comes complete with fire pit, outdoor kitchen and shower with hot water. You’ll discover a comfortable bed and cosy wood burning stove. Part of the Red Kite Estate, along with our barn and its sister tree tent, the first ever built in the UK, Dragon's Egg.",
# ...

# %%
a.head()
# Out:
#                                      ID    Category  \
# 0  f9dcbd09-32ac-41d9-a0b1-fdb2793378cf  Treehouses
# 1  1b4736a7-e73e-45bc-a9b5-d3e7fcf652fd  Treehouses
# 2  d577bc30-2222-4bef-a35e-a9825642aec4  Treehouses
# 3  ca9cbfd4-7798-4e8d-8c17-d5a64fba0abc  Treehouses
# 4  cfe479b9-c8f8-44af-9bc6-46ede9f14bb5  Treehouses
#
#                                               Title  \
# 0                 Red Kite Tree Tent - Ynys Affalon
# 1    Az Alom Cabin - Treehouse Tree to Nature Cabin
# 2                       Cabane Entre Les Pins\n🌲🏕️🌲
# 3  Tree Top Cabin with log burner & private hot tub
# 4                       Treehouse near Paris Disney
#
#                                          Description  \
# 0  [Escape to one of these two fabulous Tree Tent...
# 1  [Come and spend a romantic stay with a couple ...
# 2  [Rustic cabin between the pines, 3 meters high...
# 3  [The Tree top cabin is situated in our peacefu...
# 4  [Charming cabin nestled in the leaves, real un...
#
# ...

# %%
a.isna().sum()
# Out:
# ID                       0
# Category                 0
# Title                    0
# Description              0
# Amenities                0
# Location                 0
# guests                  15
# beds                    29
# bathrooms               65
# Price_Night              0
# Cleanliness_rating       0
# Accuracy_rating          0
# Communication_rating     0
# Location_rating          0
# Check-in_rating          0
# Value_rating             0
# amenities_count          0
# url                      0
# bedrooms                70
# dtype: int64

# %%
columns = ['guests','beds','bathrooms','bedrooms']
a[['guests','beds','bathrooms','bedrooms']] = a[['guests','beds','bathrooms','bedrooms']].fillna(1)

# %%
a.isna().sum()
# Out:
# ID                      0
# Category                0
# Title                   0
# Description             0
# Amenities               0
# Location                0
# guests                  0
# beds                    0
# bathrooms               0
# Price_Night             0
# Cleanliness_rating      0
# Accuracy_rating         0
# Communication_rating    0
# Location_rating         0
# Check-in_rating         0
# Value_rating            0
# amenities_count         0
# url                     0
# bedrooms                0
# dtype: int64

# %%
a.tail(20)
# Out:
#                                        ID    Category  \
# 809  586a0771-d9c5-45f6-be33-60bf27e70dc7  Beachfront
# 810  4b959d3d-dda4-44a7-8643-76660d61362d  Beachfront
# 811  f698b2c1-4e0c-4838-8ff3-d003544a507e  Beachfront
# 812  9d996a3b-d814-4c09-bc1c-6a42885d973e  Beachfront
# 813  587f94f0-10cc-4732-bcd0-3b251eae281e  Beachfront
# 814  fa2f231f-0ed2-4d7f-b168-4e6a541a0584  Beachfront
# 815  715c12d2-fc65-4e4b-80a9-f25193f04bc1  Beachfront
# 816  ec9cc612-1aa1-42b2-bb3a-3bcf6295a605  Beachfront
# 817  52be2b71-55f8-40d2-a5d8-4701def79537  Beachfront
# 818  ee3e3a3f-05e2-4d53-a431-7cc47a7450a8  Beachfront
# 819  87666dad-3043-4eb7-b575-97caed97b5cd  Beachfront
# 820  6f4f4c5f-c9a6-4d97-aadd-f58ff3f0a278  Beachfront
# 821  b274e60f-48e7-4b0b-8c1a-c40b63fe4ad4  Beachfront
# 822  915acb10-4ece-4f8d-91aa-d777f707af66  Beachfront
# 823  9908bb34-9461-40c1-acf2-3ebc9810377d  Beachfront
# 824  cfbc88da-e88c-415a-b397-108d0948c4ba  Beachfront
# ...

# %%
import pandas as pd
from ast import literal_eval
from pathlib import Path


class AirbnbDataPrep:
    def __init__(self):
        self.df = pd.read_csv('/Users/akmalpopalzi/Documents/GitHub/modelling-airbnbs-property-listing-dataset-/airbnb-property-listings/tabular_data/listing.csv')

    def initial_cleaning(self):
        self.df.Category = self.df.Category.astype('category')
        self.df.drop(index = 586, inplace = True)
        self.df.drop('Unnamed: 19', axis = 1, inplace = True)
        self.df.reset_index(drop = True, inplace = True)
        
        
        
    def remove_rows_with_missing_ratings(self):
        self.df.dropna(subset = ['Description','Cleanliness_rating','Accuracy_rating',"Communication_rating","Location_rating","Check-in_rating","Value_rating"], inplace = True)
        self.df.reset_index(drop = True, inplace = True)

    
    def clean_description_strings(self):
        # convert string into list of strings
        for i in range(len(self.df.Description)):
            self.df.Description[i] = literal_eval(self.df.Description[i])

        # remove extra words and phrases
        phrases = ['About this space',
           'The space',
           '',
           "  ",
           " ",
           'Other things to note',
           'Guest access']
        
        for index, value in enumerate(self.df.Description):
             for desc_index, desc in enumerate(value):
                  if desc in phrases:
                       self.df.Description[index].pop(desc_index)


    def set_feature_values(self):
        self.df[['guests','beds','bathrooms','bedrooms']] = self.df[['guests','beds','bathrooms','bedrooms']].fillna(1)


    def clean_tabular_data(self):
        self.initial_cleaning()
        self.remove_rows_with_missing_ratings()
        self.clean_description_strings()
        self.set_feature_values()
        new_df = self.df.copy()
        return new_df

# %%
data = AirbnbDataPrep()

# %%
x = data.clean_tabular_data()
# Out:
# /var/folders/j7/wpvkrkss313_f_v160vb65h80000gn/T/ipykernel_1557/224297417.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df.Description[i] = literal_eval(self.df.Description[i])

# %%
x.isna().sum()
# Out:
# ID                      0
# Category                0
# Title                   0
# Description             0
# Amenities               0
# Location                0
# guests                  0
# beds                    0
# bathrooms               0
# Price_Night             0
# Cleanliness_rating      0
# Accuracy_rating         0
# Communication_rating    0
# Location_rating         0
# Check-in_rating         0
# Value_rating            0
# amenities_count         0
# url                     0
# bedrooms                0
# dtype: int64

# %%
x
# Out:
#                                        ID    Category  \
# 0    f9dcbd09-32ac-41d9-a0b1-fdb2793378cf  Treehouses
# 1    1b4736a7-e73e-45bc-a9b5-d3e7fcf652fd  Treehouses
# 2    d577bc30-2222-4bef-a35e-a9825642aec4  Treehouses
# 3    ca9cbfd4-7798-4e8d-8c17-d5a64fba0abc  Treehouses
# 4    cfe479b9-c8f8-44af-9bc6-46ede9f14bb5  Treehouses
# ..                                    ...         ...
# 824  cfbc88da-e88c-415a-b397-108d0948c4ba  Beachfront
# 825  4fea5054-f999-4c07-addc-67e4d893deab  Beachfront
# 826  282118e2-049e-4d9f-b2f2-b47477881b07  Beachfront
# 827  9ebf9cec-624e-480e-8704-dffa7cb1fe51  Beachfront
# 828  d2b06c80-c643-485d-a24b-15d0811a3166  Beachfront
#
#                                                  Title  \
# 0                    Red Kite Tree Tent - Ynys Affalon
# 1       Az Alom Cabin - Treehouse Tree to Nature Cabin
# 2                          Cabane Entre Les Pins\n🌲🏕️🌲
# 3     Tree Top Cabin with log burner & private hot tub
# ...

# %%
x.Description[2]
# Out:
# ['Rustic cabin between the pines, 3 meters high and 28 square meters on the banks of the Austreberth River 🌲🏕️🌲',
#  "The space\nOur cabin between the pines is a great alternative for those looking for contact with nature and want to rest, enjoy together or have fun with family or friends. With 3 meters high and 28 square meters, it accommodates 4 people. Located on a 1.2 hectare property by the river Austreberthe, our rustic treehouse shares the space with our garden rabbits and dumplings, as well as wild dumplings and our beloved khenty mare, who loves apples and carrots. A tranquil retreat, with efficient thermal insulation and heaters for the colder days. Equipped with a double bed, sofa bed, kitchen , duvet and toilet.\n\n\nWe provide:\nTowels\nBed linens and pillows\nKitchen detergent and bathroom soap\nPaper towels & toilet paper\nCooking utensils\nCoffee, tea, salt and pepper, herbs of provence\nWhat to do in the area's guide\n\nI'll follow us on Instagram @entreespins",
# ...
